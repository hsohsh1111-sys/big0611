# %%
pip install pandas
# Out:
# ...
#   Using cached tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB 1.4 MB/s eta 0:00:08
#     --------------------------------------- 0.2/9.9 MB 3.5 MB/s eta 0:00:03
#    -- ------------------------------------- 0.5/9.9 MB 4.7 MB/s eta 0:00:02
#    --- ------------------------------------ 0.8/9.9 MB 4.8 MB/s eta 0:00:02
#    --- ------------------------------------ 0.9/9.9 MB 4.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.2/9.9 MB 4.8 MB/s eta 0:00:02
#    ------ --------------------------------- 1.5/9.9 MB 5.1 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/9.9 MB 5.2 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/9.9 MB 5.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/9.9 MB 5.8 MB/s eta 0:00:02
#    ------------ --------------------------- 3.0/9.9 MB 6.1 MB/s eta 0:00:02
# ...

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
temperatures = pd.Series(
    [23.5, 25.1, 19.8, 30.2],
    index=['월', '화', '수', '목'],
    name='온도')
print(temperatures)
# Out:
# 월    23.5
# 화    25.1
# 수    19.8
# 목    30.2
# Name: 온도, dtype: float64

# %%
weather_data = pd.DataFrame({
    '온도': [23.5, 25.1, 19.8, 30.2],
    '습도': [60, 65, 70, 55],
    '강수량': [0, 0, 5.2, 0]
}, index=['월', '화', '수', '목'])

print(weather_data)
# Out:
#      온도  습도  강수량
# 월  23.5  60  0.0
# 화  25.1  65  0.0
# 수  19.8  70  5.2
# 목  30.2  55  0.0

# %%
import pandas as pd
import numpy as np

# %%
data_array = np.array([
    [23.5, 60, 0],
    [19.2, 65, 0],
    [19.8, 70, 5.2],
    [30.2, 55, 0]
])
print(data_array)
print(data_array[0][0])
# Out:
# [[23.5 60.   0. ]
#  [19.2 65.   0. ]
#  [19.8 70.   5.2]
#  [30.2 55.   0. ]]
# 23.5

# %%
print(weather_data.loc['수'])
print(weather_data.loc['월','온도'])
# Out:
# 온도     19.8
# 습도     70.0
# 강수량     5.2
# Name: 수, dtype: float64
# 23.5
