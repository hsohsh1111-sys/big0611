# %%
import seaborn as sns
import pandas as pd

# %%
x= [1, 2, 3, 4, 5]
y= [10, 20, 25, 30, 42]
sns.lineplot(x=x, y=y)
# Out:
# <Axes: >

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df = sns.load_dataset('tips')
sns.lineplot(x=df['tip'], y=df['size'], orient='y')
# Out:
# <Axes: xlabel='tip', ylabel='size'>

# %%
print('min:{}, max:{}'.format(
    min(df[df['size'] == 5]['tip']),
    max(df[df['size'] == 5]['tip']) 
))
# Out:
# min:2.0, max:5.14

# %%
sns.lineplot(x=df['size'], y=df['tip'], errorbar=("ci", 95))
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.lineplot(x=df['tip'], y=df['total_bill'], errorbar=('ci', 95))
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
y= [1, 2, 3, 4, 5]
x= [10, 20, 25, 30, 42]
sns.lineplot(x=x, y=y)
# Out:
# <Axes: >

# %%
sns.lineplot(x=df['day'], y=df['total_bill'], hue=df['tip'],  errorbar=None)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
