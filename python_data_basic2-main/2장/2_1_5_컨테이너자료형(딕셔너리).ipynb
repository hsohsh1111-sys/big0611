# %%
# 딕셔너리 생성
my_dict = {
    "name":"Harry",
    "age": 27,
    "height": 190,
    "weight" : 99.9
}

my_dict
# Out:
# '.venv (3.11.9) (Python 3.11.9)'(으)로 셀을 실행하려면 ipykernel 패키지가 필요합니다.
#
# 'ipykernel'을(를) Python 환경에 설치합니다.
#
# 명령: 'c:/황상옥/git/big0611/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
# 아이템 선택/추가
my_dict.keys()

# %%
my_dict['age']

# %%
my_dict['age'] = 28
my_dict

# %%
my_dict.update({'weight': 100})
my_dict

# %%
my_dict.update({'address': 'Busan'})
my_dict

# %%
# 아이템 삭제
my_dict.popitem()

# %%
my_dict
# Out:
# {'name': 'Harry', 'age': 28, 'height': 190, 'weight': 100}

# %%
my_dict.pop('age')
# Out:
# 28

# %%
my_dict
# Out:
# {'name': 'Harry', 'height': 190, 'weight': 100}

# %%
my_dict.clear()

# %%
my_dict
# Out:
# {}
