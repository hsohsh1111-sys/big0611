# %%
print('파일을 실행하기 : shift+enter')
print('파일을 실행하기 : shift+enter')

# %%
print('파일을 실행하기 : shift+enter')

# %%
print('파일을 실행하기 : shift+enter')
