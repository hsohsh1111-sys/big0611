# %%
import mod1

print(add(1, 4))
print(sub(4, 2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 import mod1
#       2
# ----> 3 print(add(1, 4))
#       4 print(sub(4, 2))
#
# NameError: name 'add' is not defined

# %%
import mod1

# %%
import mod2
print(mod2.PI)
# Out:
# 3.141592

# %%
a = mod2.Math()
print(a.solv(2))
# Out:
# 12.566368

# %%
print(mod2.add(mod2.PI, 4.4))
# Out:
# 7.5415920000000005

# %%
import sys

# %%
sys.path
# Out:
# ['C:\\Users\\pc06-00\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip',
#  'C:\\Users\\pc06-00\\AppData\\Local\\Programs\\Python\\Python311\\DLLs',
#  'C:\\Users\\pc06-00\\AppData\\Local\\Programs\\Python\\Python311\\Lib',
#  'C:\\Users\\pc06-00\\AppData\\Local\\Programs\\Python\\Python311',
#  'c:\\황상옥\\git\\big0611\\.venv',
#  '',
#  'c:\\황상옥\\git\\big0611\\.venv\\Lib\\site-packages']

# %%
sys.path.append(r"C:\황상옥\git\big0611\py\p04_머신러닝과딥러닝\ch01_문법정리\mymod")

# %%
import mod2
print(mod2.add(3, 4))
# Out:
# 7

# %%
# %env PYTHONPATH=C:\황상옥\git\big0611\py\p04_머신러닝과딥러닝\ch01_문법정리\mymod
# Out:
# env: PYTHONPATH=C:\황상옥\git\big0611\py\p04_머신러닝과딥러닝\ch01_문법정리\mymod

# %%
import mod2
print(mod2.add(3, 4))
# Out:
# 7
